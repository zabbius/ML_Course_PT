# %% [markdown]
# <a href="https://colab.research.google.com/github/Murcha1990/ML_Course_PT/blob/main/Lecture3_Data%26Trees/DGA_improvements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задачи классификации

# %% [markdown]
# Импорт библиотек

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from math import log2

from tqdm import tqdm
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Обнаружение DGA-доменов
#
# Эта задача посвящена выявлению алгоритмически сгенерированных доменов второго уровня (SLD) в доменных именах. Ваша задача — построить модель машинного обучения, способную отличать легитимные домены от SLD, сгенерированных с помощью DGA.
#
# **Цель**
#
# Цель — обнаружение алгоритмически сгенерированных доменов второго уровня (SLD), которые часто используются вредоносным ПО для обхода механизмов обнаружения. У нас есть датасет доменных имен с метками: DGA (1) или легитимный (0). Обратите внимание, что в некоторых примерах предоставляется только SLD без домена верхнего уровня (TLD).
#
# Поскольку ложноположительные срабатывания (когда легитимный домен ошибочно классифицируется как DGA) могут приводить к серьезным проблемам, минимизация ложноположительных ошибок важнее, чем минимизация ложноотрицательных.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.2)

# %% [markdown]
# Скачаем тренировочный датасет по ссылке.

# %%
# или скачать файл train.csv с kaggle

# !wget -O dga.csv "https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/f2Z4w-xHheenKg"
# Out:
# --2026-02-09 13:48:15--  https://getfile.dokpub.com/yandex/get/https://disk.yandex.ru/d/f2Z4w-xHheenKg
# Resolving getfile.dokpub.com (getfile.dokpub.com)... 138.199.175.196
# Connecting to getfile.dokpub.com (getfile.dokpub.com)|138.199.175.196|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://downloader.disk.yandex.ru/disk/1f67bfe7341ffa80d69cb411d5812bc1f14ed2b176ceee68ee380be7b728ba12/698a081c/0F8ZdSEE6bEiq3zgKLsJP05XO4AC9ufyrXMW5UgtacVTptX9sWjOnpcHQpu7iCbA3x-wCfRFjW8x1tXXep-8yA%3D%3D?uid=0&filename=train_dga.csv&disposition=attachment&hash=ES%2BZaDNM863i5u9PjpBnP1sJhtbTnNSlZg%2Btb04JzVMo4tv58hzotGiOIsxkjVRPq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=text%2Fcsv&owner_uid=259847718&fsize=331518539&hid=2e72185b076ef407efbf7bedfed36b5f&media_type=data&tknv=v3 [following]
# --2026-02-09 13:48:15--  https://downloader.disk.yandex.ru/disk/1f67bfe7341ffa80d69cb411d5812bc1f14ed2b176ceee68ee380be7b728ba12/698a081c/0F8ZdSEE6bEiq3zgKLsJP05XO4AC9ufyrXMW5UgtacVTptX9sWjOnpcHQpu7iCbA3x-wCfRFjW8x1tXXep-8yA%3D%3D?uid=0&filename=train_dga.csv&disposition=attachment&hash=ES%2BZaDNM863i5u9PjpBnP1sJhtbTnNSlZg%2Btb04JzVMo4tv58hzotGiOIsxkjVRPq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=text%2Fcsv&owner_uid=259847718&fsize=331518539&hid=2e72185b076ef407efbf7bedfed36b5f&media_type=data&tknv=v3
# Resolving downloader.disk.yandex.ru (downloader.disk.yandex.ru)... 77.88.21.127, 2a02:6b8::2:127
# Connecting to downloader.disk.yandex.ru (downloader.disk.yandex.ru)|77.88.21.127|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s332vla.storage.yandex.net/rdisk/1f67bfe7341ffa80d69cb411d5812bc1f14ed2b176ceee68ee380be7b728ba12/698a081c/0F8ZdSEE6bEiq3zgKLsJP05XO4AC9ufyrXMW5UgtacVTptX9sWjOnpcHQpu7iCbA3x-wCfRFjW8x1tXXep-8yA==?uid=0&filename=train_dga.csv&disposition=attachment&hash=ES%2BZaDNM863i5u9PjpBnP1sJhtbTnNSlZg%2Btb04JzVMo4tv58hzotGiOIsxkjVRPq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=text%2Fcsv&owner_uid=259847718&fsize=331518539&hid=2e72185b076ef407efbf7bedfed36b5f&media_type=data&tknv=v3&ts=64a66723d3f00&s=5b875a423014e96c6c4446fa133fd03bb020d368f0d4a43220db5bed9fc9ab35&pb=U2FsdGVkX18BA5lp8xg3fpMrNozlUzuVowQHQNexqqgB40WMgyj5dXUu2d2LsPj10NTSug0IPn02cobPJGADbwqTinNI7h4Qs2moHtS_0TU [following]
# --2026-02-09 13:48:17--  https://s332vla.storage.yandex.net/rdisk/1f67bfe7341ffa80d69cb411d5812bc1f14ed2b176ceee68ee380be7b728ba12/698a081c/0F8ZdSEE6bEiq3zgKLsJP05XO4AC9ufyrXMW5UgtacVTptX9sWjOnpcHQpu7iCbA3x-wCfRFjW8x1tXXep-8yA==?uid=0&filename=train_dga.csv&disposition=attachment&hash=ES%2BZaDNM863i5u9PjpBnP1sJhtbTnNSlZg%2Btb04JzVMo4tv58hzotGiOIsxkjVRPq/J6bpmRyOJonT3VoXnDag%3D%3D%3A&limit=0&content_type=text%2Fcsv&owner_uid=259847718&fsize=331518539&hid=2e72185b076ef407efbf7bedfed36b5f&media_type=data&tknv=v3&ts=64a66723d3f00&s=5b875a423014e96c6c4446fa133fd03bb020d368f0d4a43220db5bed9fc9ab35&pb=U2FsdGVkX18BA5lp8xg3fpMrNozlUzuVowQHQNexqqgB40WMgyj5dXUu2d2LsPj10NTSug0IPn02cobPJGADbwqTinNI7h4Qs2moHtS_0TU
# Resolving s332vla.storage.yandex.net (s332vla.storage.yandex.net)... 77.88.56.210, 2a02:6b8:c0e:a86:0:41af:fe57:5fa7
# Connecting to s332vla.storage.yandex.net (s332vla.storage.yandex.net)|77.88.56.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 331518539 (316M) [text/csv]
# Saving to: ‘dga.csv’
#
# dga.csv             100%[===================>] 316.16M  19.4MB/s    in 16s
#
# 2026-02-09 13:48:34 (19.3 MB/s) - ‘dga.csv’ saved [331518539/331518539]

# %%
import numpy as np
import pandas as pd

from pathlib import Path
from math import log2

from tqdm import tqdm
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# %% [markdown]
# Посмотрим на данные

# %%
data = pd.read_csv("dga.csv")

data.head()
# Out:
#                            domain  label
# 0             c4wfahorcxq41ps0g0u      1
# 1           goievinskycattederifg      1
# 2         ypqbo2g854e4sb7re8i2e2e      1
# 3  cmikleasuredehydratorysagp.com      1
# 4                 apodoc.saarland      0

# %%
data.sample(10)
# Out:
#                                domain  label
# 14091683                     debate21      0
# 8343889            quadnfbqqanvbufnvi      1
# 9274539                    rhrwyykczl      1
# 14385891                  xjshmen.com      1
# 14676856                       gbdcpa      0
# 17562702                     aaswssmc      1
# 13301793                  hyzhihe.com      0
# 248393                         tipo-e      0
# 10884448                  jkwwlvbgrgh      1
# 12373574  1omz50d1jfw6q91ejpdpcg7b0r4      1

# %% [markdown]
# Посмотрим на баланс классов

# %%
data['label'].value_counts(normalize=True)
# Out:
# label
# 0    0.555226
# 1    0.444774
# Name: proportion, dtype: float64

# %%
len(data)
# Out:
# 17719790

# %%
data = data.sample(800_000, random_state=42)

len(data)
# Out:
# 800000

# %% [markdown]
# ### Feature engineering
#
# Самая важная честь - придумать признаки, на которых мы будем решать задачу.

# %%
VOWELS = set("aeiou") # множество гласных букв

def shannon_entropy(s):
    probs = [s.count(c) / len(s) for c in set(s)]
    return -sum(p * log2(p) for p in probs)

def digit_ratio(name):
    length = len(name)
    digits = sum(c.isdigit() for c in name)
    return digits / max(1, length)

def letter_count(name):
    return sum(c.isalpha() for c in name)

def has_digits(name):
    return int(any(c.isdigit() for c in name))

def vowel_ratio(name):
    letters = sum(c.isalpha() for c in name)
    vowels = sum(c in VOWELS for c in name)
    return vowels / max(1, letters)

def extract_features(domain):
    name = domain.split('.')[0]

    length = len(name)                                      # длина
    digits = sum(c.isdigit() for c in name)                 # количество цифр
    has_digits_flag = digits > 0                            # есть ли цифры
    letters = sum(c.isalpha() for c in name)                # количество букв
    entropy = shannon_entropy(name) if length > 0 else 0    # энтропия
    has_dash_flag = "-" in name                             # есть ли дефис
    dash_count = name.count("-")                            # количество дефисов
    digit_ratio_value = digit_ratio(name)                   # доля цифр
    dot_count = domain.count(".")                           # количество точек
    vowel_ratio_value = vowel_ratio(name)                   # доля гласных

    return [
        length,
        digits,
        int(has_digits_flag),
        letters,
        entropy,
        int(has_dash_flag),
        dash_count,
        digit_ratio_value,
        dot_count,
        vowel_ratio_value,
    ]

# %% [markdown]
# Разобъем данные на train и test

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
len(train), len(test)
# Out:
# (600000, 200000)

# %%
X_train = np.array([
    extract_features(str(d))
    for d in tqdm(train["domain"], desc="Extracting train features") # прогресс-бар
])

y_train = train["label"].values

X_test = np.array([
    extract_features(str(d))
    for d in tqdm(test["domain"], desc="Extracting test features")
])

y_test = test["label"].values
# Out:
# Extracting train features: 100%|██████████| 600000/600000 [00:10<00:00, 58692.74it/s]
# Extracting test features: 100%|██████████| 200000/200000 [00:02<00:00, 67924.11it/s]

# %% [markdown]
# Перед применением модели давайте масштабируем признаки!

# %%
model = make_pipeline(
    StandardScaler(),
    LogisticRegression( # используем простую модель логрега
        max_iter=100,
        random_state=0
    )
)

# %%
model.fit(X_train, y_train) # обучаем модель
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(random_state=0))])

# %% [markdown]
# Оценим качество получившейся модели

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import fbeta_score

y_test_pred = model.predict(X_test) # предсказываем на валидационной выборке

fbeta = fbeta_score(y_test, y_test_pred, beta=0.5) # вычисляем f_beta скор
print(fbeta)
# Out:
# 0.7655874251751622

# %% [markdown]
# Давайте посмотрим и на остальные показатели, для этого есть функция classification_report

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_test_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7899    0.8312    0.8100    110702
#            1     0.7762    0.7259    0.7502     89298
#
#     accuracy                         0.7842    200000
#    macro avg     0.7830    0.7785    0.7801    200000
# weighted avg     0.7838    0.7842    0.7833    200000

# %% [markdown]
# classification_report вывел значения **precision**, **recall**, **F1-score** и **support** для каждого класса:
#
# - **0** — нормальные домены
# - **1** — DGA-домены
#
# Также выводятся:
#
# - **accuracy** — общая доля правильных предсказаний
#
# - **macro avg** — среднее арифметическое метрик по классам
#
# - **weighted avg** — среднее метрик, взвешенное по количеству объектов каждого класса

# %% [markdown]
# ## Улучшаем решение

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

f2_scorer = make_scorer(fbeta_score, beta=2)

params = {'logisticregression__class_weight' : [None, 'balanced'],
          'logisticregression__C' : [0.5, 1., 2.]}

gs = GridSearchCV(model, params, verbose=3, scoring=f2_scorer)
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END logisticregression__C=0.5, logisticregression__class_weight=None;, score=0.735 total time=   3.3s
# [CV 2/5] END logisticregression__C=0.5, logisticregression__class_weight=None;, score=0.734 total time=   3.3s
# [CV 3/5] END logisticregression__C=0.5, logisticregression__class_weight=None;, score=0.733 total time=   3.3s
# [CV 4/5] END logisticregression__C=0.5, logisticregression__class_weight=None;, score=0.734 total time=   2.7s
# [CV 5/5] END logisticregression__C=0.5, logisticregression__class_weight=None;, score=0.739 total time=   2.6s
# [CV 1/5] END logisticregression__C=0.5, logisticregression__class_weight=balanced;, score=0.767 total time=   2.5s
# [CV 2/5] END logisticregression__C=0.5, logisticregression__class_weight=balanced;, score=0.768 total time=   3.5s
# [CV 3/5] END logisticregression__C=0.5, logisticregression__class_weight=balanced;, score=0.766 total time=   3.3s
# [CV 4/5] END logisticregression__C=0.5, logisticregression__class_weight=balanced;, score=0.766 total time=   2.7s
# [CV 5/5] END logisticregression__C=0.5, logisticregression__class_weight=balanced;, score=0.771 total time=   2.8s
# [CV 1/5] END logisticregression__C=1.0, logisticregression__class_weight=None;, score=0.736 total time=   6.2s
# [CV 2/5] END logisticregression__C=1.0, logisticregression__class_weight=None;, score=0.735 total time=   3.1s
# [CV 3/5] END logisticregression__C=1.0, logisticregression__class_weight=None;, score=0.733 total time=   2.7s
# [CV 4/5] END logisticregression__C=1.0, logisticregression__class_weight=None;, score=0.734 total time=   2.8s
# [CV 5/5] END logisticregression__C=1.0, logisticregression__class_weight=None;, score=0.739 total time=   3.7s
# [CV 1/5] END logisticregression__C=1.0, logisticregression__class_weight=balanced;, score=0.767 total time=   2.8s
# [CV 2/5] END logisticregression__C=1.0, logisticregression__class_weight=balanced;, score=0.768 total time=   2.4s
# [CV 3/5] END logisticregression__C=1.0, logisticregression__class_weight=balanced;, score=0.766 total time=   2.8s
# [CV 4/5] END logisticregression__C=1.0, logisticregression__class_weight=balanced;, score=0.766 total time=   2.7s
# [CV 5/5] END logisticregression__C=1.0, logisticregression__class_weight=balanced;, score=0.771 total time=   5.2s
# [CV 1/5] END logisticregression__C=2.0, logisticregression__class_weight=None;, score=0.735 total time=   3.4s
# [CV 2/5] END logisticregression__C=2.0, logisticregression__class_weight=None;, score=0.735 total time=   3.3s
# [CV 3/5] END logisticregression__C=2.0, logisticregression__class_weight=None;, score=0.733 total time=   3.6s
# [CV 4/5] END logisticregression__C=2.0, logisticregression__class_weight=None;, score=0.734 total time=   3.3s
# [CV 5/5] END logisticregression__C=2.0, logisticregression__class_weight=None;, score=0.739 total time=   2.5s
# [CV 1/5] END logisticregression__C=2.0, logisticregression__class_weight=balanced;, score=0.767 total time=   2.6s
# [CV 2/5] END logisticregression__C=2.0, logisticregression__class_weight=balanced;, score=0.768 total time=   2.3s
# [CV 3/5] END logisticregression__C=2.0, logisticregression__class_weight=balanced;, score=0.766 total time=   3.9s
# [CV 4/5] END logisticregression__C=2.0, logisticregression__class_weight=balanced;, score=0.766 total time=   2.8s
# [CV 5/5] END logisticregression__C=2.0, logisticregression__class_weight=balanced;, score=0.771 total time=   2.8s
# GridSearchCV(estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('logisticregression',
#                                         LogisticRegression(random_state=0))]),
#              param_grid={'logisticregression__C': [0.5, 1.0, 2.0],
#                          'logisticregression__class_weight': [None,
#                                                               'balanced']},
#              scoring=make_scorer(fbeta_score, response_method='predict', beta=2),
#              verbose=3)

# %%
gs.best_score_, gs.best_estimator_, gs.best_params_
# Out:
# (np.float64(0.7679104244570201),
#  Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(class_weight='balanced', random_state=0))]),
#  {'logisticregression__C': 1.0,
#   'logisticregression__class_weight': 'balanced'})

# %% [markdown]
# ## Улучшаем дальше

# %%
# !pip install catboost -q

# %%
from catboost import CatBoostClassifier

cb = CatBoostClassifier(n_estimators=100)

# %%
cb.fit(X_train, y_train) # обучаем модель
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.5398999	total: 188ms	remaining: 18.6s
# 1:	learn: 0.4809292	total: 361ms	remaining: 17.7s
# 2:	learn: 0.4491989	total: 524ms	remaining: 17s
# 3:	learn: 0.4291427	total: 638ms	remaining: 15.3s
# 4:	learn: 0.4182796	total: 763ms	remaining: 14.5s
# 5:	learn: 0.4103889	total: 950ms	remaining: 14.9s
# 6:	learn: 0.4048187	total: 1.13s	remaining: 15.1s
# 7:	learn: 0.4013649	total: 1.23s	remaining: 14.1s
# 8:	learn: 0.3978402	total: 1.38s	remaining: 13.9s
# 9:	learn: 0.3950283	total: 1.53s	remaining: 13.8s
# 10:	learn: 0.3925870	total: 1.69s	remaining: 13.7s
# 11:	learn: 0.3907383	total: 1.83s	remaining: 13.5s
# 12:	learn: 0.3894415	total: 1.98s	remaining: 13.3s
# 13:	learn: 0.3867095	total: 2.13s	remaining: 13.1s
# 14:	learn: 0.3857633	total: 2.31s	remaining: 13.1s
# 15:	learn: 0.3845934	total: 2.47s	remaining: 13s
# 16:	learn: 0.3839776	total: 2.59s	remaining: 12.7s
# 17:	learn: 0.3828419	total: 2.69s	remaining: 12.2s
# 18:	learn: 0.3813041	total: 2.84s	remaining: 12.1s
# 19:	learn: 0.3804231	total: 2.98s	remaining: 11.9s
# 20:	learn: 0.3795669	total: 3.05s	remaining: 11.5s
# 21:	learn: 0.3786897	total: 3.13s	remaining: 11.1s
# 22:	learn: 0.3781475	total: 3.2s	remaining: 10.7s
# 23:	learn: 0.3777948	total: 3.27s	remaining: 10.4s
# 24:	learn: 0.3773177	total: 3.35s	remaining: 10.1s
# 25:	learn: 0.3768460	total: 3.43s	remaining: 9.77s
# 26:	learn: 0.3763604	total: 3.51s	remaining: 9.49s
# 27:	learn: 0.3758556	total: 3.6s	remaining: 9.25s
# 28:	learn: 0.3752924	total: 3.67s	remaining: 8.99s
# 29:	learn: 0.3747939	total: 3.76s	remaining: 8.77s
# 30:	learn: 0.3742228	total: 3.84s	remaining: 8.55s
# 31:	learn: 0.3740689	total: 3.9s	remaining: 8.29s
# 32:	learn: 0.3736752	total: 3.99s	remaining: 8.09s
# 33:	learn: 0.3733584	total: 4.06s	remaining: 7.89s
# 34:	learn: 0.3730536	total: 4.15s	remaining: 7.7s
# 35:	learn: 0.3728291	total: 4.22s	remaining: 7.5s
# 36:	learn: 0.3725268	total: 4.29s	remaining: 7.3s
# 37:	learn: 0.3716796	total: 4.37s	remaining: 7.13s
# 38:	learn: 0.3715472	total: 4.44s	remaining: 6.95s
# 39:	learn: 0.3713226	total: 4.54s	remaining: 6.8s
# 40:	learn: 0.3712414	total: 4.64s	remaining: 6.68s
# 41:	learn: 0.3711148	total: 4.77s	remaining: 6.59s
# 42:	learn: 0.3706573	total: 4.93s	remaining: 6.54s
# 43:	learn: 0.3706216	total: 5.05s	remaining: 6.43s
# 44:	learn: 0.3705187	total: 5.19s	remaining: 6.34s
# 45:	learn: 0.3701209	total: 5.34s	remaining: 6.27s
# 46:	learn: 0.3699203	total: 5.49s	remaining: 6.19s
# 47:	learn: 0.3697476	total: 5.64s	remaining: 6.12s
# 48:	learn: 0.3695970	total: 5.79s	remaining: 6.03s
# 49:	learn: 0.3694368	total: 5.96s	remaining: 5.96s
# 50:	learn: 0.3693567	total: 6.1s	remaining: 5.87s
# 51:	learn: 0.3692499	total: 6.26s	remaining: 5.78s
# 52:	learn: 0.3692141	total: 6.39s	remaining: 5.67s
# 53:	learn: 0.3691385	total: 6.53s	remaining: 5.56s
# 54:	learn: 0.3690503	total: 6.68s	remaining: 5.47s
# 55:	learn: 0.3690073	total: 6.81s	remaining: 5.35s
# 56:	learn: 0.3689204	total: 6.93s	remaining: 5.23s
# 57:	learn: 0.3686286	total: 7.09s	remaining: 5.14s
# 58:	learn: 0.3685132	total: 7.22s	remaining: 5.02s
# 59:	learn: 0.3683823	total: 7.38s	remaining: 4.92s
# 60:	learn: 0.3682140	total: 7.53s	remaining: 4.81s
# 61:	learn: 0.3681897	total: 7.64s	remaining: 4.68s
# 62:	learn: 0.3681318	total: 7.72s	remaining: 4.54s
# 63:	learn: 0.3680595	total: 7.8s	remaining: 4.39s
# 64:	learn: 0.3679567	total: 7.88s	remaining: 4.24s
# 65:	learn: 0.3678844	total: 7.95s	remaining: 4.09s
# 66:	learn: 0.3678378	total: 8.01s	remaining: 3.95s
# 67:	learn: 0.3676550	total: 8.09s	remaining: 3.81s
# 68:	learn: 0.3675918	total: 8.17s	remaining: 3.67s
# 69:	learn: 0.3675459	total: 8.25s	remaining: 3.53s
# 70:	learn: 0.3675123	total: 8.32s	remaining: 3.4s
# 71:	learn: 0.3673730	total: 8.39s	remaining: 3.26s
# 72:	learn: 0.3673268	total: 8.46s	remaining: 3.13s
# 73:	learn: 0.3672770	total: 8.53s	remaining: 3s
# 74:	learn: 0.3671854	total: 8.6s	remaining: 2.87s
# 75:	learn: 0.3670993	total: 8.68s	remaining: 2.74s
# 76:	learn: 0.3668778	total: 8.78s	remaining: 2.62s
# 77:	learn: 0.3667299	total: 8.85s	remaining: 2.5s
# 78:	learn: 0.3666933	total: 8.92s	remaining: 2.37s
# 79:	learn: 0.3666050	total: 8.99s	remaining: 2.25s
# 80:	learn: 0.3665663	total: 9.07s	remaining: 2.13s
# 81:	learn: 0.3664590	total: 9.14s	remaining: 2.01s
# 82:	learn: 0.3663712	total: 9.22s	remaining: 1.89s
# 83:	learn: 0.3662921	total: 9.29s	remaining: 1.77s
# 84:	learn: 0.3662609	total: 9.36s	remaining: 1.65s
# 85:	learn: 0.3662208	total: 9.43s	remaining: 1.53s
# 86:	learn: 0.3661765	total: 9.5s	remaining: 1.42s
# 87:	learn: 0.3660723	total: 9.58s	remaining: 1.31s
# 88:	learn: 0.3660585	total: 9.66s	remaining: 1.19s
# 89:	learn: 0.3659545	total: 9.73s	remaining: 1.08s
# 90:	learn: 0.3659290	total: 9.81s	remaining: 971ms
# 91:	learn: 0.3659148	total: 9.88s	remaining: 859ms
# 92:	learn: 0.3658839	total: 9.95s	remaining: 749ms
# 93:	learn: 0.3657887	total: 10s	remaining: 640ms
# 94:	learn: 0.3657124	total: 10.1s	remaining: 532ms
# 95:	learn: 0.3656303	total: 10.2s	remaining: 424ms
# 96:	learn: 0.3655778	total: 10.3s	remaining: 317ms
# 97:	learn: 0.3655444	total: 10.3s	remaining: 211ms
# 98:	learn: 0.3654872	total: 10.4s	remaining: 105ms
# 99:	learn: 0.3653727	total: 10.5s	remaining: 0us

# %%
cb_pred = cb.predict(X_test)

fbeta = fbeta_score(y_test, cb_pred, beta=0.5) # вычисляем f_beta скор
print(fbeta)
# Out:
# 0.8267002224043076

# %% [markdown]
# ## Подбор порога

# %%
fbmax = -1
thmax = -1

cb_train_probs = cb.predict_proba(X_train)[:,1]

for th in tqdm(np.arange(0.01, 1.01, 0.05)):
    classes = cb_train_probs > th

    fbeta = fbeta_score(y_train, classes, beta=0.5) # вычисляем f_beta скор
    if fbeta > fbmax:
      fbmax = fbeta
      thmax = th

fbmax, thmax
# Out:
# 100%|██████████| 20/20 [00:01<00:00, 16.20it/s]
# (0.8420797980856041, np.float64(0.66))

# %%
cb_test_probs = cb.predict_proba(X_test)[:,1]
classes = cb_test_probs > thmax

fbeta = fbeta_score(y_test, classes, beta=0.5) # вычисляем f_beta скор
fbeta
# Out:
# 0.8429967930601584
